# %%
#leer txt

def leer_archivo(nombre_archivo):
    try:
        with open(nombre_archivo, "r") as archivo:
            contenido = archivo.read()
            print(contenido)
    except FileNotFoundError:
        print(f"El archivo '{nombre_archivo}' no existe.")

nombre_archivo = "tareas.txt"

leer_archivo(nombre_archivo)
# Out:
# #Mi tarea de matematicas
#
# #Manuel Jesús Castro Pech
#
# #Jimenez Poot
#
# #archivo.txt

# %%
#leer pdf

import PyPDF2

def leer_archivo_pdf(nombre_archivo):
    try:
        with open(nombre_archivo, "rb") as archivo:
            pdf_reader = PyPDF2.PdfReader(archivo)  # Cambia PdfFileReader a PdfReader
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                print(page.extract_text())
    except FileNotFoundError:
        print(f"El archivo '{nombre_archivo}' no existe.")

nombre_archivo_pdf = "ININ.pdf"
leer_archivo_pdf(nombre_archivo_pdf)
# Out:
# UNIVERSIDAD
# TECNOLÓGICA
# DE
# CANCÚN
# ACTIVIDAD:
# FASES
# 1
# Y
# 2
# DE
# “ININ”
# MATERIA:
# EXPERIENCIA
# DE
# USUARIO
# PROFESOR:
# JOSE
# LUIS
# HERRERA
# SANCHEZ
# GRUPO:
# IDYGS73
# EQUIPO:
# CASTAÑEDA
# DZUL
# JAIME
# ALEJANDRO
# CASTRO
# PECH
# MANUEL
# JESÚS
# MORALES
# GARCÍA
# ANA
# TERESA
# SANCHEZ
# MARTIN
# DIEGO
# ALDAIR
# Fase
# 1:
# Análisis
# General
# Fondo
# Sectorial
# de
# investigaci
# ón
# GrandForwar
# d
# LinkedIn
# V.A
# Publicaciones
# x
# ✔
# ✔
# Dentro
# de
# la
# presente
# aplicación
# se
# podrá
# encontrar
# una
# funcionalidad
# que
# permita
# agregar
# publicaciones
# para
# recaudar
# recursos.
# Filtros
# x
# ✔
# ✔
# Se
# contará
# con
# un
# sistema
# de
# búsqueda
# y
# filtrado
# por
# categorías
# para
# que
# la
# información
# se
# accesible
# para
# quien
# lo
# necesite
# Comentarios
# x
# x
# ✔
# Así
# mismo
# dentro
# de
# la
# aplicación
# se
# tendrá
# la
# posibilidad
# de
# comentar
# publicaciones
# para
# pedir
# informes
# Perfiles
# x
# x
# ✔
# Se
# contara
# con
# un
# sistema
# de
# perfiles
# para
# inversionistas
# e
# investigadore
# s
# Preguntas
# frecuentes
# x
# x
# x
# Para
# facilitar
# el
# uso
# de
# la
# aplicación
# se
# tendrá
# un
# apartado
# de
# preguntas
# frecuentes
# con
# información
# de
# utilidad
# para
# solucionar
# algún
# posible
# fallo
# dentro
# de
# la
# app
# Objetivos
# 1.
# Aumentar
# el
# número
# de
# usuarios
# registrados
# en
# ININ
# :
# Para
# el
# primer
# año
# de
# operación,
# el
# objetivo
# es
# alcanzar
# 5,000
# usuarios
# registrados
# en
# la
# plataforma.
# Esto
# se
# medirá
# mediante
# el
# número
# de
# cuentas
# de
# usuario
# activas
# en
# el
# sistema.
# 2.
# Fomentar
# la
# colaboración
# entre
# inversores
# y
# emprendedores
# :
# Durante
# los
# primeros
# seis
# meses,
# se
# busca
# que
# al
# menos
# el
# 20%
# de
# los
# investigadores
# que
# presenten
# sus
# ideas
# encuentren
# inversores
# interesados
# en
# su
# proyecto
# a
# través
# de
# la
# plataforma.
# Este
# objetivo
# se
# medirá
# a
# través
# de
# encuestas
# y
# seguimiento
# de
# proyectos
# financiados.
# 3.
# Crear
# una
# comunidad
# activa
# de
# inversores
# e
# inversionistas:
# En
# los
# primeros
# nueve
# meses,
# se
# pretende
# que
# el
# 30%
# de
# los
# usuarios
# realicen
# al
# menos
# un
# comentario
# o
# publicación
# en
# ININ.
# Esto
# se
# medirá
# mediante
# el
# análisis
# de
# la
# actividad
# en
# la
# plataforma
# y
# el
# número
# de
# interacciones.
# 4.
# Ampliar
# la
# presencia
# geográfica
# :
# Después
# del
# primer
# año,
# se
# planifica
# expandir
# el
# servicio
# de
# ININ
# a
# otros
# estados
# de
# México,
# además
# de
# Quintana
# Roo.
# El
# objetivo
# es
# estar
# operando
# en
# al
# menos
# tres
# estados
# adicionales.
# Esto
# se
# medirá
# mediante
# la
# apertura
# de
# cuentas
# en
# nuevos
# lugares.
# 5.
# Mejorar
# la
# satisfacción
# del
# usuario
# :
# Mantener
# una
# calificación
# promedio
# de
# al
# menos
# 4.5
# en
# una
# escala
# de
# 5
# en
# las
# revisiones
# y
# retroalimentación
# de
# los
# usuarios
# en
# cuanto
# a
# la
# experiencia
# de
# uso
# de
# la
# aplicación.
# Esto
# se
# medirá
# mediante
# encuestas
# y
# reseñas
# de
# usuarios.
# Cronograma.
#
# Costo.
# Trabajo
# de
# 8
# semanas
# que
# equivale
# a
# 56
# días
# de
# los
# cuales
# solo
# se
# trabajarán
# 40
# (quitando
# sábado
# y
# domingo
# de
# las
# 8
# semanas)
# en
# los
# cuales
# se
# invertirán
# 3
# horas
# diarias,
# tomando
# en
# cuenta
# la
# hora
# pagada
# a
# $250
# MXN.
# Tendríamos
# un
# costo
# de
# $10,000
# MXN.
#
# Fase
# 2:
# Diseño
# -Mapa
# de
# sitio
# Inicio
# Propuestas
# Investigadores
# Propuestas
# Inversores
# Perfíl
# del
# usuario
# ●
# Propuestas
# de
# investigadores.
# ●
# Propuestas
# de
# inversores.
# ●
# Términos
# y
# condiciones.
# ●
# Preguntas.
# frecuentes.
# ●
# Perfíl.
# ●
# Ver
# propuestas
# ●
# Ver
# propuestas
# ●
# Iniciar
# sesión
# ●
# Ver
# perfil
# ●
# Editar
# perfil
# -Prototipo
# https://www .figma.com/proto/bKfuGql61yo863zpJZOA5R/ININ?type=design&node-
# id=1-4&t=l1bA8OtfMZcT eYqP-1&scaling=scale-down&page-id=0%3A1&starting-poi
# nt-node-id=1%3A2&mode=design
# -Layout
# Presentación
# en
# sitio
# web
#
# App
#
#
#
#
#
# -Wireframe
# Página
# web
# de
# presentación
# App
#
#
#
# Tipografía
# -Arquitectura
# de
# la
# información
# Será
# del
# tipo
# “Lista
# anidada”,
# porque
# será
# una
# aplicación
# móvil
# en
# donde
# podrán
# acceder
# a
# un
# navegador
# y
# moverse
# libremente.

# %%
from docx import Document

path = 'A1U3Matematicas.docx'

# Abre el documento Word
doc = Document(path)

# Itera a través de los párrafos del documento
for paragraph in doc.paragraphs:
    print(paragraph.text)
# Out:
# Universidad Tecnológica de Cancún
#
# Actividad:
#     Actividad 1 unidad 3
# Carrera:
# ING. EN DESARROLLO Y GESTIÓN DE SOFTWARE
#
# Maestro:
# Gustavo Adolfo Falarco Pulido
#
# Asignatura:
# Matemáticas para ingeniería
#
# Grupo:
# IDYGS73
#
# Integrantes:
# Castro Pech Manuel Jesús
# Cedillo Escalante Aaron Jafet
# Jiménez Poot Yesenia
#
#
# Investiguen los conceptos de:
# Integración doble:
# La integración doble se refiere a la extensión del cálculo integral de una variable a dos variables. Se utiliza para calcular áreas bajo superficies bidimensionales, como regiones en un plano cartesiano. La notación típica para una integral doble es:
#
# Donde D representa el dominio de integración, f(x,y) es la función a integrar, y dA es un elemento de área en el plano.
# Las integrales dobles son esenciales en la teoría de probabilidad, la física, la estadística y la geometría, entre otros campos.
#
# Integración Triple:
# La integración triple extiende aún más el cálculo integral al tratar con tres variables. Se utiliza para calcular volúmenes en espacios tridimensionales, como sólidos en el espacio tridimensional. La notación típica para una integral triple es:
#
# Donde V representa el dominio de integración, f(x,y,z) es la función a integrar, y dV es un elemento de volumen en el espacio tridimensional.
# Las integrales triples son fundamentales en la física, la ingeniería, la estadística, y cualquier campo que involucre volúmenes en el espacio tridimensional.
#
# Caracteristicas-cálculo de areas y volumenes-aplicaciones:
# Características del Cálculo de Áreas y Volúmenes:
# Bidimensional vs. Tridimensional: El cálculo de áreas se refiere a la medición de regiones bidimensionales en un plano, mientras que el cálculo de volúmenes se refiere a la medición de espacios tridimensionales. El cálculo de áreas implica encontrar el tamaño de superficies, mientras que el cálculo de volúmenes se centra en determinar el espacio ocupado por un objeto en tres dimensiones.
# Integración: Para áreas y volúmenes de formas no simples, el cálculo integral es una herramienta fundamental. Las integrales se utilizan para sumar infinitamente pequeñas secciones de una figura o sólido, lo que permite calcular áreas y volúmenes precisos.
# Métodos de Aproximación: En casos en los que no se puede aplicar la integración, se utilizan métodos de aproximación, como la división en regiones más simples, el conteo de cuadrados o rectángulos en una cuadrícula, o la descomposición en elementos más manejables.
#
# Aplicaciones del Cálculo de Áreas y Volúmenes:
# Geometría: El cálculo de áreas y volúmenes es fundamental en geometría para medir y comparar formas y figuras. Se utiliza para determinar áreas de triángulos, cuadriláteros, círculos, y para calcular volúmenes de poliedros y sólidos geométricos.
# Física: En física, se aplican conceptos de cálculo de áreas y volúmenes para resolver problemas relacionados con la cinemática, la dinámica, y la termodinámica. Por ejemplo, se utilizan para determinar la densidad de objetos y calcular momentos de inercia.
# Ingeniería: Los ingenieros utilizan cálculos de áreas y volúmenes para diseñar estructuras, calcular la capacidad de almacenamiento, y determinar la resistencia y capacidad de carga de materiales y componentes.
# Estadística: En estadísticas, el cálculo de áreas bajo curvas de distribución de probabilidad es esencial para calcular probabilidades y realizar inferencias estadísticas.
# Topografía y Cartografía: La medición precisa de áreas en mapas y planos topográficos se basa en el cálculo de áreas. Esto es importante para la planificación urbana, la gestión de recursos y la navegación.
# Economía y Negocios: En el ámbito financiero, se utilizan cálculos de áreas y volúmenes para estimar la oferta y la demanda, así como para analizar datos económicos.
# Biología y Ecología: El cálculo de áreas y volúmenes se aplica en el estudio de hábitats, poblaciones, y en la determinación de la distribución de especies.
# Medicina: En medicina, se utilizan conceptos de cálculo de volúmenes para determinar el volumen de órganos y estructuras del cuerpo en estudios de diagnóstico por imágenes.
#
#
#
#
# Grafica de funciones:
# Función:
# Una función matemática es una regla o relación que asigna un valor único de un conjunto (llamado dominio) a un valor único de otro conjunto (llamado codominio). En términos más simples, para cada entrada en el dominio, hay una única salida en el codominio.
# Dominio y Codominio:
# El dominio de una función es el conjunto de todos los valores de entrada posibles para esa función. El codominio es el conjunto de todos los valores de salida posibles. La gráfica de una función muestra cómo los valores del dominio se relacionan con los valores del codominio.
# Ejes Coordenados:
# Para representar una gráfica de una función, se suelen utilizar ejes coordenados, que son dos líneas perpendiculares que se cruzan en un punto llamado origen. Un eje es horizontal y se llama eje x, mientras que el otro es vertical y se llama eje y.
# Puntos en el Plano:
# Los puntos en el plano cartesiano se utilizan para representar pares ordenados que corresponden a los valores en el dominio y el codominio de la función. Un punto típico en el plano está dado por (x,y), donde x es el valor en el dominio y Y es el valor en el codominio.
# Conexión de Puntos:
# Para crear una gráfica de una función, se traza una serie de puntos en el plano cartesiano según las reglas de la función. Luego, se suelen unir estos puntos con una línea suave o una curva para mostrar la tendencia general de la función.
# Interpretación Visual:
# La gráfica de una función permite una interpretación visual de la función. Puede mostrar tendencias, patrones, extremos, puntos de intersección y comportamientos notables de la función. Es una herramienta valiosa para comprender y analizar cómo cambian las variables.
# Representación de Funciones Elementales:
# Las funciones elementales, como funciones lineales, cuadráticas, exponenciales, logarítmicas y trigonométricas, se representan comúnmente a través de gráficas que muestran sus propiedades distintivas.
#
# Uso en Resolución de Problemas:
# Las gráficas de funciones se utilizan en la resolución de problemas en una amplia gama de campos, como matemáticas, ciencias naturales, ingeniería, economía y muchas otras disciplinas. Ayudan a visualizar y entender cómo cambian las cantidades a medida que se modifican los valores de entrada.
# Herramientas de Software:
# Existen numerosas herramientas de software, como software de cálculo simbólico y software de gráficos, que facilitan la creación y visualización de gráficas de funciones de manera rápida y precisa.
#
# Problemario Resuelto:

# %%
import pandas as pd

# Ruta al archivo Excel
path = 'Myexel.xlsx'

# Carga el archivo Excel en un DataFrame de pandas
df = pd.read_excel(path)

# Muestra el contenido del DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: [castro pech manuel jesus]
# Index: []
